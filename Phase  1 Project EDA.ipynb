# %%
import pandas as pd

# %%
films = '/Users/Arsh/Downloads/blockbusters.csv'

# %%
m = pd.read_csv(films)

# %%
m.head()
# Out:
#   Main_Genre    Genre_2    Genre_3  imdb_rating  length  rank_in_year rating  \
# 0     Action  Adventure      Drama          7.4     135             1  PG-13
# 1     Action  Adventure     Sci-Fi          8.5     156             2  PG-13
# 2  Animation     Action  Adventure          7.8     118             3     PG
# 3     Action  Adventure      Drama          6.2     129             4  PG-13
# 4     Action     Comedy        NaN          7.8     119             5      R
#
#                  studio                           title worldwide_gross  year
# 0  Walt Disney Pictures                   Black Panther    $700,059,566  2018
# 1  Walt Disney Pictures          Avengers: Infinity War    $678,815,482  2018
# 2                 Pixar                   Incredibles 2    $608,581,744  2018
# 3    Universal Pictures  Jurassic World: Fallen Kingdom    $416,769,345  2018
# 4      20th Century Fox                      Deadpool 2    $318,491,426  2018

# %%
import matplotlib.pyplot as plt

# %%
m['imdb_rating'].astype(float)
# Out:
# 0      7.4
# 1      8.5
# 2      7.8
# 3      6.2
# 4      7.8
#       ...
# 432    7.1
# 433    6.4
# 434    6.2
# 435    6.0
# 436    6.4
# Name: imdb_rating, Length: 437, dtype: float64

# %%
m['worldwide_gross'] = m['worldwide_gross'].str.replace('$', '')
m['worldwide_gross'] = m['worldwide_gross'].str.replace(',', '')
m['worldwide_gross'] = m['worldwide_gross'].astype(float)

# %%
m['worldwide_gross'] = m['worldwide_gross'].astype(int)

# %%
newdf = m.loc[m['year'] >= 2000]
newdf
# Out:
#     Main_Genre    Genre_2    Genre_3  imdb_rating  length  rank_in_year  \
# 0       Action  Adventure      Drama          7.4     135             1
# 1       Action  Adventure     Sci-Fi          8.5     156             2
# 2    Animation     Action  Adventure          7.8     118             3
# 3       Action  Adventure      Drama          6.2     129             4
# 4       Action     Comedy        NaN          7.8     119             5
# ..         ...        ...        ...          ...     ...           ...
# 185    Fantasy     Family     Comedy          6.0     104             6
# 186     Comedy        NaN        NaN          7.0     108             7
# 187      Drama  Adventure     Action          6.4     130             8
# 188     Sci-Fi  Adventure     Action          7.4     104             9
# 189   Thriller     Horror      Drama          6.6     130            10
#
#     rating                studio                           title  \
# ...

# %%
newdf.groupby('Main_Genre')['worldwide_gross'].mean().sort_values(ascending=False)
# Out:
# Main_Genre
# Fantasy      8.428503e+08
# Adventure    7.005133e+08
# Sci-Fi       6.763367e+08
# Comedy       6.506474e+08
# Thriller     6.323585e+08
# Drama        5.625680e+08
# Animation    5.269178e+08
# History      4.567590e+08
# War          4.560682e+08
# Crime        4.268867e+08
# Family       4.196656e+08
# Romance      4.125427e+08
# Action       4.032829e+08
# Music        3.518679e+08
# Horror       3.274817e+08
# Name: worldwide_gross, dtype: float64

# %%
newdf.groupby('Main_Genre')['worldwide_gross'].sum().sort_values(ascending=False)
# Out:
# Main_Genre
# Fantasy      31185461422
# Sci-Fi       19613764811
# Comedy       15615536700
# Thriller     12647170801
# Animation    11592191168
# Action       10888637115
# Adventure     5604106108
# Drama         3375407780
# Romance       2887799069
# Crime         1707546871
# Music          703735892
# History        456758981
# War            456068181
# Family         419665568
# Horror         327481748
# Name: worldwide_gross, dtype: int64

# %%
newdf.groupby('Main_Genre')['worldwide_gross'].median().sort_values(ascending=False)
# Out:
# Main_Genre
# Fantasy      829685377.0
# Adventure    785201187.0
# Sci-Fi       691247768.0
# Thriller     588547275.0
# Comedy       569114687.5
# Animation    532212922.5
# Drama        504078892.0
# History      456758981.0
# War          456068181.0
# Crime        455089318.0
# Family       419665568.0
# Romance      374111707.0
# Action       363070709.0
# Music        351867946.0
# Horror       327481748.0
# Name: worldwide_gross, dtype: float64

# %%
newdf.groupby('Genre_2')['worldwide_gross'].mean().sort_values(ascending=False)
# Out:
# Genre_2
# Family       7.781579e+08
# Animation    6.716606e+08
# Adventure    6.457242e+08
# Crime        6.450558e+08
# Action       6.400673e+08
# Sci-Fi       6.333296e+08
# Musical      6.098277e+08
# Mystery      6.070187e+08
# Drama        5.360412e+08
# Fantasy      5.202552e+08
# Comedy       4.473255e+08
# Horror       2.914204e+08
# Music        2.703954e+08
# Name: worldwide_gross, dtype: float64

# %%
newdf.groupby('Genre_2')['worldwide_gross'].sum().sort_values(ascending=False)
# Out:
# Genre_2
# Adventure    56178005868
# Animation    13433212714
# Family        9337894915
# Action        8960942428
# Comedy        8051859144
# Drama         6432494339
# Crime         3225278955
# Sci-Fi        3166648135
# Fantasy       2601276123
# Mystery       2428074623
# Musical        609827661
# Horror         291420351
# Music          270395425
# Name: worldwide_gross, dtype: int64

# %%
y = newdf.groupby('Main_Genre')['worldwide_gross'].mean().sort_values(ascending=False)
f = y.head(10)
f
# Out:
# Main_Genre
# Fantasy      8.428503e+08
# Adventure    7.005133e+08
# Sci-Fi       6.763367e+08
# Comedy       6.506474e+08
# Thriller     6.323585e+08
# Drama        5.625680e+08
# Animation    5.269178e+08
# History      4.567590e+08
# War          4.560682e+08
# Crime        4.268867e+08
# Name: worldwide_gross, dtype: float64

# %%
y = f / 1000000

# %%
s = list(f.keys())
d = list(y)
fig, ax = plt.subplots(figsize=(20,10))
plt.bar(s, d, color ='blue')
plt.xlabel("Genre", fontsize = 30)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)
ax.set_yticks(range(0,1000,100))
plt.ylabel("Revenue in ($) Millions", fontsize = 30)
plt.title("Average Blockbuster Revenue by Genre (2000-2018)", fontsize = 40)
plt.show()

# %%
budgets = pd.read_csv('/Users/Arsh/Downloads/tn.movie_budgets.csv.gz')
budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
reviews = pd.read_csv('/Users/Arsh/Downloads/tmdb.movies.csv.gz')
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
gross = pd.read_csv('/Users/Arsh/Downloads/bom.movie_gross.csv.gz')
gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
gross = gross.drop('studio', axis=1)
gross.head()
# Out:
#                                          title  domestic_gross foreign_gross  \
# 0                                  Toy Story 3     415000000.0     652000000
# 1                   Alice in Wonderland (2010)     334200000.0     691300000
# 2  Harry Potter and the Deathly Hallows Part 1     296000000.0     664300000
# 3                                    Inception     292600000.0     535700000
# 4                          Shrek Forever After     238700000.0     513900000
#
#    year
# 0  2010
# 1  2010
# 2  2010
# 3  2010
# 4  2010

# %%
gross = gross.fillna(0)

# %%
gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   domestic_gross  3387 non-null   float64
#  2   foreign_gross   3387 non-null   object
#  3   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 106.0+ KB

# %%
gross['foreign_gross'] = gross['foreign_gross'].str.replace(',', '')

# %%
gross['foreign_gross'] = gross['foreign_gross'].astype(float)

# %%
gross['foreign_gross'] = gross['foreign_gross'].fillna(0)

# %%
gross['total_gross'] = gross['domestic_gross'] + gross['foreign_gross']

# %%
gross.isna().sum()
# Out:
# title             0
# domestic_gross    0
# foreign_gross     0
# year              0
# total_gross       0
# dtype: int64

# %%
moviesbygross = gross.sort_values(by='total_gross', ascending=False) 
moviesbygross
# Out:
#                                             title  domestic_gross  \
# 727                         Marvel's The Avengers     623400000.0
# 1875                      Avengers: Age of Ultron     459000000.0
# 3080                                Black Panther     700100000.0
# 328   Harry Potter and the Deathly Hallows Part 2     381000000.0
# 2758                     Star Wars: The Last Jedi     620200000.0
# ...                                           ...             ...
# 3078                                         2:22           400.0
# 2756                        News From Planet Mars           300.0
# 2757                                      Satanic           300.0
# 2321                              The Chambermaid           300.0
# 1476                                   Storage 24           100.0
#
#       foreign_gross  year   total_gross
# 727     895500000.0  2012  1.518900e+09
# 1875    946400000.0  2015  1.405400e+09
# 3080    646900000.0  2018  1.347000e+09
# ...

# %%
moviesbygross = moviesbygross.loc[moviesbygross['year'] >= 2001]
moviesbygross = moviesbygross.loc[moviesbygross['total_gross'] >= 50000000]
# Out:
#                                             title  domestic_gross  \
# 727                         Marvel's The Avengers     623400000.0
# 1875                      Avengers: Age of Ultron     459000000.0
# 3080                                Black Panther     700100000.0
# 328   Harry Potter and the Deathly Hallows Part 2     381000000.0
# 2758                     Star Wars: The Last Jedi     620200000.0
# ...                                           ...             ...
# 1974                                The Himalayas        697000.0
# 1581                Dragon Ball Z: Battle of Gods       2600000.0
# 827                                     Red Tails      49900000.0
# 828                           Monsters, Inc. (3D)      34000000.0
# 1233                                 Delivery Man      30700000.0
#
#       foreign_gross  year   total_gross
# 727     895500000.0  2012  1.518900e+09
# 1875    946400000.0  2015  1.405400e+09
# 3080    646900000.0  2018  1.347000e+09
# ...

# %%
moviesbygross.to_csv('moviesbygross.csv', index=False)

# %%
moviesbygross['Domestic Gross (in millions)'] = moviesbygross['domestic_gross'] / 1000000
moviesbygross['Foreign Gross (in millions)'] = moviesbygross['foreign_gross'] / 1000000
moviesbygross['Total Gross (in millions)'] = moviesbygross['total_gross'] / 1000000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-150-034f214adf89> in <module>
#       2 moviesbygross['Foreign Gross (in millions)'] = moviesbygross['foreign_gross'] / 1000000
#       3 moviesbygross['Total Gross (in millions)'] = moviesbygross['total_gross'] / 1000000
# ----> 4 moviesbygross.drop('domestic_gross', 'foreign_gross', 'total_gross', 'Domestic gross (in millions)', 'Foreign gross (in millions)', axis =1)
#
# TypeError: drop() got multiple values for argument 'axis'

# %%
moviesbygross
# Out:
#                                             title  year  \
# 727                         Marvel's The Avengers  2012
# 1875                      Avengers: Age of Ultron  2015
# 3080                                Black Panther  2018
# 328   Harry Potter and the Deathly Hallows Part 2  2011
# 2758                     Star Wars: The Last Jedi  2017
# ...                                           ...   ...
# 1974                                The Himalayas  2015
# 1581                Dragon Ball Z: Battle of Gods  2014
# 827                                     Red Tails  2012
# 828                           Monsters, Inc. (3D)  2012
# 1233                                 Delivery Man  2013
#
#       Domestic Gross (in millions)  Foreign Gross (in millions)  \
# 727                        623.400                      895.500
# 1875                       459.000                      946.400
# 3080                       700.100                      646.900
# ...

# %%
moviesbygross = moviesbygross.drop('Total gross (in millions)', axis =1)

# %%
gd4 = pd.read_csv('/Users/Arsh/Downloads/rt.reviews.tsv.gz', delimiter="\t")
gd4.info()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa0 in position 4: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-94-1b73170a62e6> in <module>
# ----> 1 gd4 = pd.read_csv('/Users/Arsh/Downloads/rt.reviews.tsv.gz', delimiter="\t")
#       2 gd4.info()
#
# ...

# %%
summary = pd.read_csv('/Users/Arsh/Downloads/rt.movie_info.tsv.gz', delimiter="\t")
summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
summary.shape
# Out:
# (1560, 12)

# %%
summary.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
summary.notna().sum()
# Out:
# id              1560
# synopsis        1498
# rating          1557
# genre           1552
# director        1361
# writer          1111
# theater_date    1201
# dvd_date        1201
# currency         340
# box_office       340
# runtime         1530
# studio           494
# dtype: int64

# %%
newsummary = summary.loc[m['year'] >= 2000]
newsummary[]

summary.shape

# %%
gd6 = pd.read_csv('/Users/Arsh/Downloads/tn.movie_budgets.csv.gz')
gd6.info()

# %%
budgets = pd.read_csv('/Users/Arsh/Downloads/tn.movie_budgets.csv.gz')
budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
budgets.isna().sum()
# Out:
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
budgets['production_budget'] = budgets['production_budget'].str.replace(',', '')
budgets['production_budget'] = budgets['production_budget'].str.replace('$', '')
budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0         425000000   $760,507,625  $2,776,345,279
# 1         410600000   $241,063,875  $1,045,663,875
# 2         350000000    $42,762,350    $149,762,350
# 3         330600000   $459,005,868  $1,403,013,963
# 4         317000000   $620,181,382  $1,316,721,747

# %%
budgets['worldwide_gross'] = budgets['worldwide_gross'].str.replace(',', '')
budgets['worldwide_gross'] = budgets['worldwide_gross'].str.replace('$', '')
budgets['domestic_gross'] = budgets['domestic_gross'].str.replace(',', '')
budgets['domestic_gross'] = budgets['domestic_gross'].str.replace('$', '')
budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0         425000000      760507625      2776345279
# 1         410600000      241063875      1045663875
# 2         350000000       42762350       149762350
# 3         330600000      459005868      1403013963
# 4         317000000      620181382      1316721747

# %%
print(type(budgets['release_date'][0]))
# Out:
# <class 'str'>

# %%
budgets['release_date'] = budgets['release_date'].str.replace(',', '')
budgets['release_date'] = budgets['release_date'].str.replace('Jan', 'January')
budgets['release_date'] = budgets['release_date'].str.replace('Feb', 'February')
budgets['release_date'] = budgets['release_date'].str.replace('Mar', 'March')
budgets['release_date'] = budgets['release_date'].str.replace('Apr', 'April')
budgets['release_date'] = budgets['release_date'].str.replace('Jun', 'June')
budgets['release_date'] = budgets['release_date'].str.replace('Jul', 'July')
budgets['release_date'] = budgets['release_date'].str.replace('Aug', 'August')
budgets['release_date'] = budgets['release_date'].str.replace('Sep', 'September')
budgets['release_date'] = budgets['release_date'].str.replace('Oct', 'October')
budgets['release_date'] = budgets['release_date'].str.replace('Nov', 'November')
budgets['release_date'] = budgets['release_date'].str.replace('Dec', 'December')

# %%
budgets['release_date'] = pd.to_datetime(
                          budgets['release_date'],
                          format='%m%d%Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     449             try:
# --> 450                 values, tz = conversion.datetime_to_datetime64(arg)
#     451                 dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-183-9bd5544a970e> in <module>
# ----> 1 budgets['release_date'] = pd.to_datetime(
# ...

# %%
budgets['release_date'] = pd.to_datetime(budgets['release_date'])

# %%
budgets
# Out:
#       id release_date                                        movie  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78   2018-12-31                                       Red 11
# 5778  79   1999-04-02                                    Following
# 5779  80   2005-07-13                Return to the Land of Wonders
# 5780  81   2015-09-29                         A Plague So Pleasant
# 5781  82   2005-08-05                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross    release
# 0            425000000      760507625      2776345279  425000000
# ...

# %%
budgets = budgets.loc[budgets['release_date'] >= '2001-01-01']

# %%
budgets = budgets.drop('release', axis=1)
budgets
# Out:
#       id release_date                                        movie  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5776  77   2004-12-31                              The Mongol King
# 5777  78   2018-12-31                                       Red 11
# 5779  80   2005-07-13                Return to the Land of Wonders
# 5780  81   2015-09-29                         A Plague So Pleasant
# 5781  82   2005-08-05                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0            425000000      760507625      2776345279
# ...

# %%
budgets = budgets.loc[budgets['worldwide_gross'] >= 1000000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-200-18ae601d59d7> in <module>
# ----> 1 budgets = budgets.loc[budgets['worldwide_gross'] >= 1000000]
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ...

# %%
budgets['production_budget']= budgets['production_budget'].astype('int64')
budgets['domestic_gross'] = budgets['domestic_gross'].astype('int64')
budgets['worldwide_gross'] = budgets['worldwide_gross'].astype('int64')

# %%
budgets.dtypes
# Out:
# id                            int64
# release_date         datetime64[ns]
# movie                        object
# production_budget             int64
# domestic_gross                int64
# worldwide_gross               int64
# dtype: object

# %%
budgets = budgets.loc[budgets['worldwide_gross'] > 1000000]

# %%
budgets
# Out:
#       id release_date                                        movie  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5679  80   2015-07-10                                  The Gallows
# 5680  81   2006-09-29                            Facing the Giants
# 5685  86   2017-07-07                                A Ghost Story
# 5709  10   2004-05-07                                Super Size Me
# 5716  17   2001-03-16                                     Gabriela
#
#       production_budget  domestic_gross  worldwide_gross
# 0             425000000       760507625       2776345279
# ...

# %%
budgets['profit'] = budgets['worldwide_gross'] - budgets['production_budget']
budgets
# Out:
# <ipython-input-216-7e0eebdc9a98>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   budgets['profit'] = budgets['worldwide_gross'] - budgets['production_budget']
#       id release_date                                        movie  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5679  80   2015-07-10                                  The Gallows
# ...

# %%
budgets['profit_margin'] = 100 * ((budgets['worldwide_gross'] - budgets['production_budget']) / budgets['worldwide_gross'])
budgets
# Out:
# <ipython-input-217-c66d7af56fef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   budgets['profit_margin'] = 100 * ((budgets['worldwide_gross'] - budgets['production_budget']) / budgets['worldwide_gross'])
#       id release_date                                        movie  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# ...

# %%
budgets = budgets.sort_values(by='profit_margin', ascending=False)

# %%
budgets.head(20)
# Out:
#       id release_date                     movie  production_budget  \
# 5492  93   2009-09-25       Paranormal Activity             450000
# 5679  80   2015-07-10               The Gallows             100000
# 5709  10   2004-05-07             Super Size Me              65000
# 5656  57   2007-05-16                      Once             150000
# 5507   8   2004-06-11         Napoleon Dynamite             400000
# 5430  31   2004-08-06                Open Water             500000
# 5680  81   2006-09-29         Facing the Giants             100000
# 5211  12   2012-01-06          The Devil Inside            1000000
# 5459  60   2009-04-23                      Home             500000
# 5156  57   2004-10-29                       Saw            1200000
# 4247  48   2002-04-19  My Big Fat Greek Wedding            5000000
# 5428  29   2008-09-26                 Fireproof             500000
# 5062  63   2011-04-01                 Insidious            1500000
# ...

# %%
budgets = budgets.drop('domestic_profit_margin', axis=1)
budgets['domestic_profit_margin'] = (budgets['domestic_gross'] - budgets['production_budget']) / budgets['domestic_gross']
budgets
# Out:
#       id release_date                 movie  production_budget  \
# 5492  93   2009-09-25   Paranormal Activity             450000
# 5679  80   2015-07-10           The Gallows             100000
# 5709  10   2004-05-07         Super Size Me              65000
# 5507   8   2004-06-11     Napoleon Dynamite             400000
# 5680  81   2006-09-29     Facing the Giants             100000
# ...   ..          ...                   ...                ...
# 5558  59   2014-10-31  All You Need Is Love             300000
# 2451  52   2013-12-31               Metegol           22000000
# 2365  66   2007-12-31                 Flood           24000000
# 4755  56   2017-10-10               Demonic            3000000
# 619   20   2019-01-22             Renegades           77500000
#
#       domestic_gross  worldwide_gross     profit  profit_margin  \
# 5492       107918810        194183034  193733034      99.768260
# 5679        22764410         41656474   41556474      99.759941
# ...

# %%
budgets = budgets.sort_values(by='domestic_profit_margin', ascending=False) 
budgets['profit_margin'] = budgets['profit_margin'] / 100
budgets
# Out:
#       id release_date                               movie  production_budget  \
# 5492  93   2009-09-25                 Paranormal Activity             450000
# 5679  80   2015-07-10                         The Gallows             100000
# 5709  10   2004-05-07                       Super Size Me              65000
# 5507   8   2004-06-11                   Napoleon Dynamite             400000
# 5680  81   2006-09-29                   Facing the Giants             100000
# ...   ..          ...                                 ...                ...
# 1537  38   2013-04-16                  Un monstre Ã Paris           40000000
# 3938  39   2017-09-29  Don Gato, el inicio de la pandilla            8000000
# 4855  56   2009-12-31                              NiktÃ©            2400000
# 3514  15   2016-02-05                          Misconduct           11000000
# 619   20   2019-01-22                           Renegades           77500000
#
# ...

# %%
budgets = budgets.loc[budgets['domestic_gross'] > 1000000]
budgets
# Out:
#       id release_date                        movie  production_budget  \
# 5492  93   2009-09-25          Paranormal Activity             450000
# 5679  80   2015-07-10                  The Gallows             100000
# 5709  10   2004-05-07                Super Size Me              65000
# 5507   8   2004-06-11            Napoleon Dynamite             400000
# 5680  81   2006-09-29            Facing the Giants             100000
# ...   ..          ...                          ...                ...
# 1620  21   2011-05-06             There Be Dragons           36000000
# 341   42   2019-06-14  Men in Black: International          110000000
# 1201   2   2015-04-17                     Child 44           50000000
# 607    8   2005-09-02           A Sound of Thunder           80000000
# 618   19   2016-02-12            The Little Prince           77500000
#
#       domestic_gross  worldwide_gross     profit  profit_margin  \
# ...

# %%
budgets1 = budgets.loc[budgets['profit'] > 0]

# %%
budgets1
# Out:
#       id release_date                             movie  production_budget  \
# 5492  93   2009-09-25               Paranormal Activity             450000
# 5679  80   2015-07-10                       The Gallows             100000
# 5709  10   2004-05-07                     Super Size Me              65000
# 5507   8   2004-06-11                 Napoleon Dynamite             400000
# 5680  81   2006-09-29                 Facing the Giants             100000
# ...   ..          ...                               ...                ...
# 1619  20   2016-01-22                         Yip Man 3           36000000
# 841   42   2016-02-19                        Mei Ren Yu           60720000
# 2450  51   2006-03-03                      Joyeux NoÃ«l           22000000
# 823   24   2006-12-27  Perfume: The Story of a Murderer           63700000
# 618   19   2016-02-12                 The Little Prince           77500000
#
#       domestic_gross  worldwide_gross     profit  profit_margin  \
# ...

# %%
budgets2 = budgets.sort_values(by='domestic_profit_margin', ascending=True)

# %%
budgets2 = budgets.loc[budgets['profit'] <= 0]

# %%
unprofitable = budgets2

# %%
unprofitable.to_csv('unprofitable.csv', index=False)

# %%
profitable= budgets1

# %%
profitable.to_csv('profitable.csv', index=False)

# %%
profitable.head()
# Out:
#       id release_date                movie  production_budget  domestic_gross  \
# 5492  93   2009-09-25  Paranormal Activity             450000       107918810
# 5679  80   2015-07-10          The Gallows             100000        22764410
# 5709  10   2004-05-07        Super Size Me              65000        11529368
# 5507   8   2004-06-11    Napoleon Dynamite             400000        44540956
# 5680  81   2006-09-29    Facing the Giants             100000        10178331
#
#       worldwide_gross     profit  profit_margin  domestic_profit_margin
# 5492        194183034  193733034       0.009977                0.995830
# 5679         41656474   41556474       0.009976                0.995607
# 5709         22233808   22168808       0.009971                0.994362
# 5507         46122713   45722713       0.009913                0.991020
# 5680         10243159   10143159       0.009902                0.990175

# %%
profitable['profit_margin'] = profitable['profit_margin'] * 100
# Out:
# <ipython-input-258-9748b2801c8d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profitable['profit_margin'] = profitable['profit_margin'] * 100

# %%
profitable.head()
# Out:
#       id release_date                movie  production_budget  domestic_gross  \
# 5492  93   2009-09-25  Paranormal Activity             450000       107918810
# 5679  80   2015-07-10          The Gallows             100000        22764410
# 5709  10   2004-05-07        Super Size Me              65000        11529368
# 5507   8   2004-06-11    Napoleon Dynamite             400000        44540956
# 5680  81   2006-09-29    Facing the Giants             100000        10178331
#
#       worldwide_gross     profit  profit_margin  domestic_profit_margin
# 5492        194183034  193733034       0.997683                0.995830
# 5679         41656474   41556474       0.997599                0.995607
# 5709         22233808   22168808       0.997077                0.994362
# 5507         46122713   45722713       0.991327                0.991020
# 5680         10243159   10143159       0.990237                0.990175

# %%
profitable.dtypes
# Out:
# id                                 int64
# release_date              datetime64[ns]
# movie                             object
# production_budget                  int64
# domestic_gross                     int64
# worldwide_gross                    int64
# profit                             int64
# profit_margin                    float64
# domestic_profit_margin           float64
# dtype: object

# %%
profitable['cost_revenue_ratio_in_%'] = 100 * (profitable['domestic_gross'] / profitable['production_budget'])
profitable = profitable.sort_values(by='cost_revenue_ratio_in_%', ascending=False) 
profitable.to_csv('profitable.csv', index=False)

# %%
profitable.head(25)
# Out:
#       id release_date                     movie  production_budget  \
# 5492  93   2009-09-25       Paranormal Activity             450000
# 5679  80   2015-07-10               The Gallows             100000
# 5709  10   2004-05-07             Super Size Me              65000
# 5507   8   2004-06-11         Napoleon Dynamite             400000
# 5680  81   2006-09-29         Facing the Giants             100000
# 5428  29   2008-09-26                 Fireproof             500000
# 5656  57   2007-05-16                      Once             150000
# 5430  31   2004-08-06                Open Water             500000
# 5211  12   2012-01-06          The Devil Inside            1000000
# 5189  90   2014-03-21          Godâs Not Dead            1150000
# 4247  48   2002-04-19  My Big Fat Greek Wedding            5000000
# 5716  17   2001-03-16                  Gabriela              50000
# 5156  57   2004-10-29                       Saw            1200000
# ...
