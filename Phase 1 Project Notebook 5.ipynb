# %% [markdown]
# This is the notebook I will use to make data visualizations for my data. Day 2 - Thursday

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/Arsh/Flatiron/Phase 1 Film Project/thecsv')
df.shape
# Out:
# (1692, 17)

# %%
df.drop('person_id', axis=1, inplace=True)

# %%
values = ['War', 'Family', 'Western', 'Romance', 'Musical']
df = df[df.genre1.isin(values) == False]

# %% [markdown]
# I am now just limiting my dataset to only the profitable movies from the master df.

# %%
df = df[df['profitable'] == 1].sort_values(by='profit_margin', ascending = False)
df
# Out:
#          primary_title      Gross                        Distributor  \
# 0          The Gallows   22764410                       Warner Bros.
# 1     The Devil Inside   53261944                 Paramount Pictures
# 2           Unfriended   32482090                 Universal Pictures
# 3                Split  138291365                 Universal Pictures
# 4              Get Out  176040665                 Universal Pictures
# ...                ...        ...                                ...
# 1520        Alex Cross   25888412                          Lionsgate
# 1521     That's My Boy   36931089  Sony Pictures Entertainment (SPE)
# 1522               Pan   35088320                       Warner Bros.
# 1523       Firestarter    9589250                 Universal Pictures
# 1524            Stoker    1714221           Fox Searchlight Pictures
#
#       release_year  runtime_minutes       genre1    genre2 release_month  \
# 0             2015         81.00000       Horror   Mystery           Jul
# 1             2012         83.00000       Horror       NaN           Jan
# 2             2015         83.00000       Horror   Mystery           Apr
# 3             2017        107.11193        Crime       NaN           Jan
# 4             2017        104.00000       Horror   Mystery           Feb
# ...            ...              ...          ...       ...           ...
# 1520          2012        101.00000       Action     Crime           Oct
# 1521          2012        116.00000       Comedy       NaN           Jun
# 1522          2015        111.00000    Adventure    Comedy           Oct
# 1523          2022         94.00000  Documentary       NaN           May
# 1524          2013         99.00000        Drama  Thriller           Mar
#
#       production_budget  worldwide_gross            director       profit  \
# 0              100000.0       41656474.0        Travis Cluff   41556474.0
# 1             1000000.0      101759490.0  William Brent Bell  100759490.0
# 2             1000000.0       64364198.0     Levan Gabriadze   63364198.0
# 3             5000000.0      278964806.0        Robbie Walsh  273964806.0
# 4             5000000.0      255367951.0        Jordan Peele  250367951.0
# ...                 ...              ...                 ...          ...
# 1520         35000000.0       35426759.0           Rob Cohen     426759.0
# 1521         57500000.0       58085235.0         Sean Anders     585235.0
# 1522        150000000.0      151525973.0          Joe Wright    1525973.0
# 1523         15000000.0       15136870.0        Jamie Bailey     136870.0
# 1524         12000000.0       12034913.0      Chan-wook Park      34913.0
#
#       profit_margin  profitable budget_tier movie_length
# 0         99.759941        True    low_tier        short
# 1         99.017291        True    low_tier        short
# 2         98.446341        True    low_tier        short
# 3         98.207659        True    low_tier       normal
# 4         98.042041        True    low_tier       normal
# ...             ...         ...         ...          ...
# 1520       1.204623        True    mid_tier       normal
# 1521       1.007545        True   high_tier       normal
# 1522       1.007070        True   high_tier       normal
# 1523       0.904216        True    mid_tier       normal
# 1524       0.290098        True    mid_tier       normal
#
# [1516 rows x 16 columns]

# %% [markdown]
# Now i made subsets of the df based on budget tier so i can more easily wrangle and visualize data by movies grouped in each budget tier.

# %%
low =  df[df['budget_tier'] == 'low_tier'].sort_values(by='profit_margin', ascending = False)
low.shape
# Out:
# (106, 16)

# %%
low
# Out:
#                         primary_title      Gross             Distributor  \
# 0                         The Gallows   22764410            Warner Bros.
# 1                    The Devil Inside   53261944      Paramount Pictures
# 2                          Unfriended   32482090      Universal Pictures
# 3                               Split  138291365      Universal Pictures
# 4                             Get Out  176040665      Universal Pictures
# ...                               ...        ...                     ...
# 1469                 Hearts Beat Loud    2386251         Gunpowder & Sky
# 1483  The Resurrection of Gavin Stone    2303792                 BH Tilt
# 1489      The Diary of a Teenage Girl    1477002  Sony Pictures Classics
# 1500                   First Reformed    3448256                     A24
# 1509                            Locke    1375769                     A24
#
#       release_year  runtime_minutes  genre1   genre2 release_month  \
# 0             2015         81.00000  Horror  Mystery           Jul
# 1             2012         83.00000  Horror      NaN           Jan
# 2             2015         83.00000  Horror  Mystery           Apr
# 3             2017        107.11193   Crime      NaN           Jan
# 4             2017        104.00000  Horror  Mystery           Feb
# ...            ...              ...     ...      ...           ...
# 1469          2018         97.00000  Comedy    Drama           Jun
# 1483          2017         91.00000  Comedy    Drama           Jan
# 1489          2015        102.00000  Comedy    Drama           Aug
# 1500          2018        113.00000   Drama  Mystery           May
# 1509          2014         85.00000   Drama      NaN           Apr
#
#       production_budget  worldwide_gross            director       profit  \
# 0              100000.0       41656474.0        Travis Cluff   41556474.0
# 1             1000000.0      101759490.0  William Brent Bell  100759490.0
# 2             1000000.0       64364198.0     Levan Gabriadze   63364198.0
# 3             5000000.0      278964806.0        Robbie Walsh  273964806.0
# 4             5000000.0      255367951.0        Jordan Peele  250367951.0
# ...                 ...              ...                 ...          ...
# 1469          2000000.0        2420962.0         Brett Haley     420962.0
# 1483          2000000.0        2303792.0      Dallas Jenkins     303792.0
# 1489          2000000.0        2279959.0     Marielle Heller     279959.0
# 1500          3500000.0        3874772.0       Paul Schrader     374772.0
# 1509          2000000.0        2088390.0       Steven Knight      88390.0
#
#       profit_margin  profitable budget_tier movie_length
# 0         99.759941        True    low_tier        short
# 1         99.017291        True    low_tier        short
# 2         98.446341        True    low_tier        short
# 3         98.207659        True    low_tier       normal
# 4         98.042041        True    low_tier       normal
# ...             ...         ...         ...          ...
# 1469      17.388212        True    low_tier       normal
# 1483      13.186607        True    low_tier       normal
# 1489      12.279124        True    low_tier       normal
# 1500       9.672105        True    low_tier       normal
# 1509       4.232447        True    low_tier        short
#
# [106 rows x 16 columns]

# %%
low['Distributor'].value_counts().head(10)
# Out:
# A24                       11
# Universal Pictures        10
# BH Tilt                    9
# Lionsgate                  8
# Roadside Attractions       6
# Open Road Films (II)       5
# Sony Pictures Classics     5
# Paramount Pictures         5
# IFC Films                  4
# Warner Bros.               4
# Name: Distributor, dtype: int64

# %%
mid =  df[df['budget_tier'] == 'mid_tier'].sort_values(by='profit_margin', ascending = False)
mid.shape
# Out:
# (403, 16)

# %%
mid['Distributor'].value_counts().head(10)
# Out:
# Universal Pictures                   51
# Warner Bros.                         44
# Lionsgate                            43
# Twentieth Century Fox                30
# Paramount Pictures                   23
# Fox Searchlight Pictures             21
# The Weinstein Company                21
# Sony Pictures Entertainment (SPE)    19
# Focus Features                       19
# STX Entertainment                    17
# Name: Distributor, dtype: int64

# %%
high = df[df['budget_tier'] == 'high_tier'].sort_values(by='profit_margin', ascending = False)
high.shape
# Out:
# (1007, 16)

# %% [markdown]
# After this, now I will start looking through the data to see relationships between different categories and profitability.

# %%
x = low['runtime_minutes']
y = low['profit_margin']
fig, ax = plt.subplots(figsize =(12,8))
ax.scatter(x, y, s=100, alpha = 0.7, color = 'blue')
ax.set_title('Relationship between runtime and profit margin for low budget movies')
ax.set_xlabel('runtime')
ax.set_ylabel('profit_margin')
plt.tight_layout();

# %%
x = mid['runtime_minutes']
y = mid['profit_margin']
fig, ax = plt.subplots(figsize =(12,8))
ax.scatter(x, y, s=100, alpha = 0.7, color = 'blue')
ax.set_title('Relationship between runtime and profit margin for mid budget movies')
ax.set_xlabel('runtime')
ax.set_ylabel('profit_margin')
plt.tight_layout();

# %%
x = high['runtime_minutes']
y = high['profit_margin']
fig, ax = plt.subplots(figsize =(12,8))
ax.scatter(x, y, s=100, alpha = 0.7, color = 'blue')
ax.set_title('Relationship between runtime and profit margin for high budget movies')
ax.set_xlabel('runtime')
ax.set_ylabel('profit_margin')
plt.tight_layout();

# %%
x = df['runtime_minutes']
y = df['profit_margin']
fig, ax = plt.subplots(figsize =(12,8))
ax.scatter(x, y, s=100, alpha = 0.3, color = 'blue')
ax.set_title('Relationship between runtime and profit margin for all movies')
ax.set_xlabel('runtime')
ax.set_ylabel('profit_margin')
plt.tight_layout();

# %% [markdown]
# Clearly there is no linear relationship between runtime and profit margin for movies, of any budget size.

# %%
100 * low['movie_length'].value_counts(normalize=True)
# Out:
# normal    64.150943
# short     34.905660
# long       0.943396
# Name: movie_length, dtype: float64

# %%
100 * df['movie_length'].value_counts(normalize=True)
# Out:
# normal    81.596306
# short     15.039578
# long       3.364116
# Name: movie_length, dtype: float64

# %%
low
# Out:
#                         primary_title      Gross             Distributor  \
# 0                         The Gallows   22764410            Warner Bros.
# 1                    The Devil Inside   53261944      Paramount Pictures
# 2                          Unfriended   32482090      Universal Pictures
# 3                               Split  138291365      Universal Pictures
# 4                             Get Out  176040665      Universal Pictures
# ...                               ...        ...                     ...
# 1469                 Hearts Beat Loud    2386251         Gunpowder & Sky
# 1483  The Resurrection of Gavin Stone    2303792                 BH Tilt
# 1489      The Diary of a Teenage Girl    1477002  Sony Pictures Classics
# 1500                   First Reformed    3448256                     A24
# 1509                            Locke    1375769                     A24
#
#       release_year  runtime_minutes  genre1   genre2 release_month  \
# 0             2015         81.00000  Horror  Mystery           Jul
# 1             2012         83.00000  Horror      NaN           Jan
# 2             2015         83.00000  Horror  Mystery           Apr
# 3             2017        107.11193   Crime      NaN           Jan
# 4             2017        104.00000  Horror  Mystery           Feb
# ...            ...              ...     ...      ...           ...
# 1469          2018         97.00000  Comedy    Drama           Jun
# 1483          2017         91.00000  Comedy    Drama           Jan
# 1489          2015        102.00000  Comedy    Drama           Aug
# 1500          2018        113.00000   Drama  Mystery           May
# 1509          2014         85.00000   Drama      NaN           Apr
#
#       production_budget  worldwide_gross            director       profit  \
# 0              100000.0       41656474.0        Travis Cluff   41556474.0
# 1             1000000.0      101759490.0  William Brent Bell  100759490.0
# 2             1000000.0       64364198.0     Levan Gabriadze   63364198.0
# 3             5000000.0      278964806.0        Robbie Walsh  273964806.0
# 4             5000000.0      255367951.0        Jordan Peele  250367951.0
# ...                 ...              ...                 ...          ...
# 1469          2000000.0        2420962.0         Brett Haley     420962.0
# 1483          2000000.0        2303792.0      Dallas Jenkins     303792.0
# 1489          2000000.0        2279959.0     Marielle Heller     279959.0
# 1500          3500000.0        3874772.0       Paul Schrader     374772.0
# 1509          2000000.0        2088390.0       Steven Knight      88390.0
#
#       profit_margin  profitable budget_tier movie_length
# 0         99.759941        True    low_tier        short
# 1         99.017291        True    low_tier        short
# 2         98.446341        True    low_tier        short
# 3         98.207659        True    low_tier       normal
# 4         98.042041        True    low_tier       normal
# ...             ...         ...         ...          ...
# 1469      17.388212        True    low_tier       normal
# 1483      13.186607        True    low_tier       normal
# 1489      12.279124        True    low_tier       normal
# 1500       9.672105        True    low_tier       normal
# 1509       4.232447        True    low_tier        short
#
# [106 rows x 16 columns]

# %% [markdown]
# These next two lines of code give back the result of the most profitable directors in the susbset of profitable low budget movies that were released from 2012 onwards. As we can see 2 names near the top of both lists, both in in terms of absolute profit as well in terms of profit margin, are Jordan Peele and William Brent Bell. Both of these directors are well known for making horror movies.

# %%
xw = low.groupby("director").mean().sort_values(by="profit_margin", ascending=False).head(10)
xw
# Out:
#                           Gross  release_year  runtime_minutes  \
# director
# Travis Cluff         22764410.0        2015.0         81.00000
# William Brent Bell   53261944.0        2012.0         83.00000
# Levan Gabriadze      32482090.0        2015.0         83.00000
# Robbie Walsh        138291365.0        2017.0        107.11193
# Jordan Peele        176040665.0        2017.0        104.00000
# Jill Wong            27854932.0        2016.0         87.00000
# Bradley Parker       18119640.0        2012.0         86.00000
# James DeMonaco       64473115.0        2013.0         85.00000
# Fabrice Gobert       67268835.0        2016.0         87.00000
# Scott Derrickson     48086903.0        2012.0        110.00000
#
#                     production_budget  worldwide_gross       profit  \
# director
# Travis Cluff                 100000.0       41656474.0   41556474.0
# William Brent Bell          1000000.0      101759490.0  100759490.0
# Levan Gabriadze             1000000.0       64364198.0   63364198.0
# Robbie Walsh                5000000.0      278964806.0  273964806.0
# Jordan Peele                5000000.0      255367951.0  250367951.0
# Jill Wong                   1500000.0       65245512.0   63745512.0
# Bradley Parker              1000000.0       42411721.0   41411721.0
# James DeMonaco              3000000.0       91266581.0   88266581.0
# Fabrice Gobert              5000000.0      148806510.0  143806510.0
# Scott Derrickson            3000000.0       87727807.0   84727807.0
#
#                     profit_margin  profitable
# director
# Travis Cluff            99.759941        True
# William Brent Bell      99.017291        True
# Levan Gabriadze         98.446341        True
# Robbie Walsh            98.207659        True
# Jordan Peele            98.042041        True
# Jill Wong               97.700991        True
# Bradley Parker          97.642161        True
# James DeMonaco          96.712926        True
# Fabrice Gobert          96.639932        True
# Scott Derrickson        96.580332        True

# %%
xy = low.groupby("director").sum().sort_values(by="worldwide_gross", ascending=False).head(10)
xy
# Out:
#                         Gross  release_year  runtime_minutes  \
# director
# Robbie Walsh        138291365          2017        107.11193
# Jordan Peele        176040665          2017        104.00000
# Christopher Landon   88146217          4031        180.00000
# Fabrice Gobert       67268835          2016         87.00000
# Ariel Schulman       53885000          2012         88.00000
# Dan Trachtenberg     72082998          2016        103.00000
# Stiles White         50856010          2014         89.00000
# Michael Tiddes       69058109          6043        264.00000
# William Brent Bell   53261944          2012         83.00000
# M. Night Shyamalan   65206105          2015         94.00000
#
#                     production_budget  worldwide_gross       profit  \
# director
# Robbie Walsh                5000000.0      278964806.0  273964806.0
# Jordan Peele                5000000.0      255367951.0  250367951.0
# Christopher Landon         10000000.0      215915114.0  205915114.0
# Fabrice Gobert              5000000.0      148806510.0  143806510.0
# Ariel Schulman              5000000.0      142817992.0  137817992.0
# Dan Trachtenberg            5000000.0      108286422.0  103286422.0
# Stiles White                5000000.0      103300632.0   98300632.0
# Michael Tiddes             11500000.0      103242494.0   91742494.0
# William Brent Bell          1000000.0      101759490.0  100759490.0
# M. Night Shyamalan          5000000.0       98677816.0   93677816.0
#
#                     profit_margin  profitable
# director
# Robbie Walsh            98.207659           1
# Jordan Peele            98.042041           1
# Christopher Landon     190.500072           2
# Fabrice Gobert          96.639932           1
# Ariel Schulman          96.499041           1
# Dan Trachtenberg        95.382616           1
# Stiles White            95.159759           1
# Michael Tiddes         254.355071           3
# William Brent Bell      99.017291           1
# M. Night Shyamalan      94.933005           1

# %%
keys1 = low.groupby("genre1").sum().sort_values(by="profit_margin", ascending=False).head(10)
keys1
# Out:
#                  Gross  release_year  runtime_minutes  production_budget  \
# genre1
# Horror       953031683         50374       2270.00000         91100000.0
# Drama        395375538         50374       2579.00000         79450000.0
# Comedy       274444892         50372       2363.00000         64730000.0
# Action        76319722         14108        688.00000         17250000.0
# Adventure     53267994         12094        597.00000         14216000.0
# Biography     96150944         12086        642.00000         20400000.0
# Documentary   37159680         16126        711.00000         22200000.0
# Crime        147158110          4035        199.11193          6000000.0
# Animation     21321100          2014         10.00000          5000000.0
# Fantasy       12985600          2015         71.00000          2300000.0
#
#              worldwide_gross        profit  profit_margin  profitable
# genre1
# Horror          1.714667e+09  1.623567e+09    2221.067930          25
# Drama           6.915800e+08  6.121300e+08    1768.247100          25
# Comedy          3.666032e+08  3.018732e+08    1760.194736          25
# Action          1.210916e+08  1.038416e+08     560.122503           7
# Adventure       9.759712e+07  8.338112e+07     488.263541           6
# Biography       1.644372e+08  1.440372e+08     473.867798           6
# Documentary     4.620414e+07  2.400414e+07     373.080911           8
# Crime           2.953994e+08  2.893994e+08     192.122931           2
# Animation       4.182407e+07  3.682407e+07      88.045160           1
# Fantasy         1.430493e+07  1.200493e+07      83.921628           1

# %%
low.groupby("genre1").sum().sort_values(by="Gross", ascending=False).head(10)
# Out:
#                  Gross  release_year  runtime_minutes  production_budget  \
# genre1
# Horror       953031683         50374       2270.00000         91100000.0
# Drama        395375538         50374       2579.00000         79450000.0
# Comedy       274444892         50372       2363.00000         64730000.0
# Crime        147158110          4035        199.11193          6000000.0
# Biography     96150944         12086        642.00000         20400000.0
# Action        76319722         14108        688.00000         17250000.0
# Adventure     53267994         12094        597.00000         14216000.0
# Documentary   37159680         16126        711.00000         22200000.0
# Animation     21321100          2014         10.00000          5000000.0
# Fantasy       12985600          2015         71.00000          2300000.0
#
#              worldwide_gross        profit  profit_margin  profitable
# genre1
# Horror          1.714667e+09  1.623567e+09    2221.067930          25
# Drama           6.915800e+08  6.121300e+08    1768.247100          25
# Comedy          3.666032e+08  3.018732e+08    1760.194736          25
# Crime           2.953994e+08  2.893994e+08     192.122931           2
# Biography       1.644372e+08  1.440372e+08     473.867798           6
# Action          1.210916e+08  1.038416e+08     560.122503           7
# Adventure       9.759712e+07  8.338112e+07     488.263541           6
# Documentary     4.620414e+07  2.400414e+07     373.080911           8
# Animation       4.182407e+07  3.682407e+07      88.045160           1
# Fantasy         1.430493e+07  1.200493e+07      83.921628           1

# %%
low.groupby("genre2").sum().sort_values(by="Gross", ascending=False).head(10)
# Out:
#                  Gross  release_year  runtime_minutes  production_budget  \
# genre2
# Mystery      733598845         34254           1585.0         64100000.0
# Drama        222615348         44330           2157.0         52080000.0
# Thriller     172879606         16121            777.0         33000000.0
# Horror       145891690         16123            732.0         17700000.0
# Fantasy       87105387          8062            381.0         14700000.0
# Romance       62686832          8060            394.0         13000000.0
# Documentary   53565151          4027             85.0          7500000.0
# Music         41089454         12085            594.0         15750000.0
# Comedy        37040152         10073            489.0         10500000.0
# Sci-Fi        29395797          4031            197.0          6500000.0
#
#              worldwide_gross        profit  profit_margin  profitable
# genre2
# Mystery         1.370821e+09  1.306721e+09    1506.897927          17
# Drama           3.329809e+08  2.809009e+08    1588.628618          22
# Thriller        2.398665e+08  2.068665e+08     544.888729           8
# Horror          2.173588e+08  1.996588e+08     717.304779           8
# Fantasy         1.183607e+08  1.036607e+08     333.074743           4
# Romance         1.326902e+08  1.196902e+08     297.982620           4
# Documentary     7.415132e+07  6.665132e+07     180.311748           2
# Music           7.691276e+07  6.116276e+07     373.105325           6
# Comedy          7.551007e+07  6.501007e+07     385.406781           5
# Sci-Fi          4.425740e+07  3.775740e+07     169.243205           2

# %%
low.groupby("genre2").sum().sort_values(by="profit_margin", ascending=False).head(10)
# Out:
#                  Gross  release_year  runtime_minutes  production_budget  \
# genre2
# Drama        222615348         44330           2157.0         52080000.0
# Mystery      733598845         34254           1585.0         64100000.0
# Horror       145891690         16123            732.0         17700000.0
# Thriller     172879606         16121            777.0         33000000.0
# Comedy        37040152         10073            489.0         10500000.0
# Music         41089454         12085            594.0         15750000.0
# Fantasy       87105387          8062            381.0         14700000.0
# Romance       62686832          8060            394.0         13000000.0
# Crime         26203728          8056            393.0         13416000.0
# Documentary   53565151          4027             85.0          7500000.0
#
#              worldwide_gross        profit  profit_margin  profitable
# genre2
# Drama           3.329809e+08  2.809009e+08    1588.628618          22
# Mystery         1.370821e+09  1.306721e+09    1506.897927          17
# Horror          2.173588e+08  1.996588e+08     717.304779           8
# Thriller        2.398665e+08  2.068665e+08     544.888729           8
# Comedy          7.551007e+07  6.501007e+07     385.406781           5
# Music           7.691276e+07  6.116276e+07     373.105325           6
# Fantasy         1.183607e+08  1.036607e+08     333.074743           4
# Romance         1.326902e+08  1.196902e+08     297.982620           4
# Crime           4.892873e+07  3.551273e+07     243.369003           4
# Documentary     7.415132e+07  6.665132e+07     180.311748           2

# %%
xd = low.groupby("release_month").sum().sort_values(by="profit", ascending=False).head(5)
xd = xd['profit']
xd
# Out:
# release_month
# Jan    634574902.0
# Oct    588357430.0
# Feb    414219414.0
# Jul    352456735.0
# Mar    290811087.0
# Name: profit, dtype: float64

# %%
xm = low.groupby("release_month").sum().sort_values(by="profit_margin", ascending=False).head(5)
xm = xm['profit_margin']
xm
# Out:
# release_month
# Oct    1102.707943
# Mar    1023.448349
# Jul     884.073921
# Jun     840.817107
# Jan     830.065420
# Name: profit_margin, dtype: float64

# %%
xc = low.groupby("release_month").mean().sort_values(by="production_budget", ascending=False)
xc = xc['production_budget']
xc
# Out:
# release_month
# Dec    5.000000e+06
# Nov    4.000000e+06
# Mar    3.984615e+06
# Feb    3.500000e+06
# Jan    3.301000e+06
# Sep    3.150000e+06
# Oct    3.096667e+06
# Aug    2.900000e+06
# May    2.627000e+06
# Jul    2.520000e+06
# Jun    2.470000e+06
# Apr    2.190909e+06
# Name: production_budget, dtype: float64

# %% [markdown]
# Now, I am doing groupbys on genre1 on various colummns in low sorted by either profit margin or gross profit. As we can see in these groupby functions, the most profitable and high grossing months are October, March, July, or January.
# However, once we do a groupby that lists the release month by median production budget, we see that March and January have generally higher budgets than other months. For example, the median producution budget of films released in March is 5 million while it is only 3 million for October and $2.25 million in July. Therefore, if we should made a low budget movie it makes the most sense to release it in July or October, as these are very profitable months, and the costs for movies released at these times tends to be lower.

# %% [markdown]
# These next two lines of code give back the result of the most profitable directors in the susbset of profitable mid budget movies that were released from 2012 onwards. As we can see, there is one director who is both on the groupbys of directors of medium budget movies, Andy Muschietti.

# %%
mid.groupby("director").mean().sort_values(by="profit_margin", ascending=False).head(20)
# Out:
#                           Gross  release_year  runtime_minutes  \
# director
# Nitesh Tiwari        12391761.0        2016.0        161.00000
# Josh Boone          124872350.0        2014.0        126.00000
# Damien Chazelle     151101803.0        2016.0        128.00000
# David F. Sandberg   102092201.0        2017.0        109.00000
# Andy Muschietti     327481748.0        2017.0        135.00000
# John Krasinski      188024361.0        2018.0         90.00000
# Adam Robitel         67745330.0        2018.0        103.00000
# James Wan           137400141.0        2013.0        112.00000
# Morten Tyldum        91125683.0        2014.0        114.00000
# Steven Atkinson     150157400.0        2014.0        107.11193
# Tatsuya Nagamine     30712119.0        2019.0        100.00000
# Sam Taylor-Johnson  166167230.0        2015.0        125.00000
# Rob Tari            175084580.0        2019.0         75.00000
# Troy Murray          51738905.0        2016.0         70.00000
# James DeMonaco       75588087.5        2015.0        105.50000
# Justin Baldoni       45729221.0        2019.0        116.00000
# Elisa Chee          126663600.0        2014.0          9.00000
# John Madden          39745153.5        2013.5        123.00000
# Gerard McMurray      69488745.0        2018.0         98.00000
# Thea Sharrock        56245075.0        2016.0        106.00000
#
#                     production_budget  worldwide_gross       profit  \
# director
# Nitesh Tiwari               9500000.0      294654618.0  285154618.0
# Josh Boone                 12000000.0      307166834.0  295166834.0
# Damien Chazelle            20000000.0      426351163.0  406351163.0
# David F. Sandberg          15000000.0      305384865.0  290384865.0
# Andy Muschietti            35000000.0      697457969.0  662457969.0
# John Krasinski             17000000.0      334522294.0  317522294.0
# Adam Robitel               10000000.0      167885588.0  157885588.0
# James Wan                  20000000.0      318000141.0  298000141.0
# Morten Tyldum              15000000.0      227740463.0  212740463.0
# Steven Atkinson            18000000.0      270944428.0  252944428.0
# Tatsuya Nagamine            8500000.0      122747755.0  114247755.0
# Sam Taylor-Johnson         40000000.0      570998101.0  530998101.0
# Rob Tari                   20000000.0      254210310.0  234210310.0
# Troy Murray                12000000.0      149570720.0  137570720.0
# James DeMonaco              9500000.0      115024804.0  105524804.0
# Justin Baldoni              7000000.0       80504421.0   73504421.0
# Elisa Chee                 40000000.0      457507776.0  417507776.0
# John Madden                10000000.0      112512043.0  102512043.0
# Gerard McMurray            13000000.0      136617305.0  123617305.0
# Thea Sharrock              20000000.0      208265198.0  188265198.0
#
#                     profit_margin  profitable
# director
# Nitesh Tiwari           96.775886        True
# Josh Boone              96.093328        True
# Damien Chazelle         95.309031        True
# David F. Sandberg       95.088165        True
# Andy Muschietti         94.981776        True
# John Krasinski          94.918126        True
# Adam Robitel            94.043563        True
# James Wan               93.710695        True
# Morten Tyldum           93.413555        True
# Steven Atkinson         93.356571        True
# Tatsuya Nagamine        93.075230        True
# Sam Taylor-Johnson      92.994723        True
# Rob Tari                92.132498        True
# Troy Murray             91.977039        True
# James DeMonaco          91.746503        True
# Justin Baldoni          91.304825        True
# Elisa Chee              91.256979        True
# John Madden             90.754453        True
# Gerard McMurray         90.484368        True
# Thea Sharrock           90.396859        True

# %%
xn = mid.groupby("director").sum().sort_values(by="worldwide_gross", ascending=False).head(20)
xn
# Out:
#                         Gross  release_year  runtime_minutes  \
# director
# Olivier Megaton     229110711          4027        200.00000
# Andy Muschietti     327481748          2017        135.00000
# Sam Taylor-Johnson  166167230          2015        125.00000
# David O. Russell    282210765          4025        260.00000
# Peter Farrelly      171288181          4032        239.00000
# Elisa Chee          126663600          2014          9.00000
# Damien Chazelle     151101803          2016        128.00000
# Wes Ball            102427862          2014        113.00000
# Stephen Chbosky     150165757          4029        216.00000
# John Krasinski      188024361          2018         90.00000
# Greg Tiernan        197730591          4035        196.11193
# Paul Feig           213130774          4031        234.00000
# James Wan           137400141          2013        112.00000
# Steven Soderbergh   192617701          8054        427.00000
# Paul W.S. Anderson   26830068          2017        107.00000
# Scott Moore         185367956          4033        204.00000
# Tim Story           247951217          6042        330.00000
# Josh Boone          124872350          2014        126.00000
# David F. Sandberg   102092201          2017        109.00000
# Nitesh Tiwari        12391761          2016        161.00000
#
#                     production_budget  worldwide_gross       profit  \
# director
# Olivier Megaton            93000000.0      705463828.0  612463828.0
# Andy Muschietti            35000000.0      697457969.0  662457969.0
# Sam Taylor-Johnson         40000000.0      570998101.0  530998101.0
# David O. Russell           61000000.0      494290747.0  433290747.0
# Peter Farrelly             63000000.0      478588031.0  415588031.0
# Elisa Chee                 40000000.0      457507776.0  417507776.0
# Damien Chazelle            20000000.0      426351163.0  406351163.0
# Wes Ball                   34000000.0      348319861.0  314319861.0
# Stephen Chbosky            33000000.0      337674015.0  304674015.0
# John Krasinski             17000000.0      334522294.0  317522294.0
# Greg Tiernan               49000000.0      332846501.0  283846501.0
# Paul Feig                  63000000.0      327356491.0  264356491.0
# James Wan                  20000000.0      318000141.0  298000141.0
# Steven Soderbergh          89000000.0      317930862.0  228930862.0
# Paul W.S. Anderson         40000000.0      314101190.0  274101190.0
# Scott Moore                48000000.0      308709266.0  260709266.0
# Tim Story                  76000000.0      308229013.0  232229013.0
# Josh Boone                 12000000.0      307166834.0  295166834.0
# David F. Sandberg          15000000.0      305384865.0  290384865.0
# Nitesh Tiwari               9500000.0      294654618.0  285154618.0
#
#                     profit_margin  profitable
# director
# Olivier Megaton        173.439678           2
# Andy Muschietti         94.981776           1
# Sam Taylor-Johnson      92.994723           1
# David O. Russell       175.606026           2
# Peter Farrelly         167.307551           2
# Elisa Chee              91.256979           1
# Damien Chazelle         95.309031           1
# Wes Ball                90.238857           1
# Stephen Chbosky        154.122731           2
# John Krasinski          94.918126           1
# Greg Tiernan           170.892030           2
# Paul Feig              160.796418           2
# James Wan               93.710695           1
# Steven Soderbergh      222.200156           4
# Paul W.S. Anderson      87.265250           1
# Scott Moore            167.025619           2
# Tim Story              223.099234           3
# Josh Boone              96.093328           1
# David F. Sandberg       95.088165           1
# Nitesh Tiwari           96.775886           1

# %%
dl = mid.groupby("genre1").mean().sort_values(by="worldwide_gross", ascending=False).head(10)
dl = dl['worldwide_gross'].tail(9)
dl = dl.head()
dl
# Out:
# genre1
# Horror       1.162993e+08
# Action       1.014371e+08
# Adventure    9.158905e+07
# Comedy       8.828258e+07
# Drama        8.159496e+07
# Name: worldwide_gross, dtype: float64

# %%
mid.groupby("genre1").mean().sort_values(by="profit_margin", ascending=False).head(10)
# Out:
#                     Gross  release_year  runtime_minutes  production_budget  \
# genre1
# Horror       5.857974e+07   2016.037037        97.374516       1.718148e+07
# Adventure    5.213100e+07   2015.000000        96.722222       2.297222e+07
# Comedy       5.144040e+07   2014.849057       106.691847       2.197642e+07
# Drama        3.987276e+07   2014.857143       108.566186       1.906310e+07
# Action       4.600627e+07   2014.987013       108.613297       2.847662e+07
# Biography    4.500793e+07   2015.612245       119.816327       2.078571e+07
# Crime        3.437221e+07   2014.708333       112.546330       2.224583e+07
# Animation    6.643510e+07   2015.250000        77.777983       3.800000e+07
# Documentary  4.198884e+07   2015.636364        89.141786       2.290909e+07
# Fantasy      3.337636e+07   2012.500000        91.000000       2.100000e+07
#
#              worldwide_gross        profit  profit_margin  profitable
# genre1
# Horror          1.162993e+08  9.911787e+07      72.552299        True
# Adventure       9.158905e+07  6.861683e+07      66.841336        True
# Comedy          8.828258e+07  6.630616e+07      66.333032        True
# Drama           8.159496e+07  6.253186e+07      63.030586        True
# Action          1.014371e+08  7.296048e+07      59.272141        True
# Biography       8.116291e+07  6.037720e+07      58.984675        True
# Crime           6.831554e+07  4.606971e+07      58.794131        True
# Animation       1.941438e+08  1.561438e+08      58.722320        True
# Documentary     6.623146e+07  4.332237e+07      53.159135        True
# Fantasy         6.289561e+07  4.189561e+07      46.684510        True

# %%
mid.groupby("release_month").median().sort_values(by="production_budget", ascending=False)
# Out:
#                     Gross  release_year  runtime_minutes  production_budget  \
# release_month
# May            45852178.0        2016.0        106.00000         25000000.0
# Jan            30533046.0        2015.0        104.00000         24000000.0
# Aug            30837070.0        2015.0        104.50000         23500000.0
# Dec            34111733.0        2015.0        112.50000         23500000.0
# Oct            32381217.0        2015.0        106.00000         23000000.0
# Apr            32149404.0        2015.0        107.11193         22500000.0
# Feb            42930462.0        2015.0        106.00000         22000000.0
# Jul            46695870.5        2015.0        104.50000         20000000.0
# Jun            43362855.5        2015.0        106.00000         20000000.0
# Sep            27020284.0        2014.0        106.00000         20000000.0
# Nov            42158780.0        2015.0        111.00000         19000000.0
# Mar            40826341.0        2015.0        106.00000         13000000.0
#
#                worldwide_gross      profit  profit_margin  profitable
# release_month
# May                 68848446.0  51603136.0      67.818347        True
# Jan                 69669665.0  45694078.5      68.224811        True
# Aug                 56719364.0  34848757.5      60.938880        True
# Dec                 52649266.0  36890523.0      68.597129        True
# Oct                 71009334.0  41837234.0      63.596439        True
# Apr                 61623819.0  34404202.0      63.128816        True
# Feb                 64179495.0  42907734.0      69.681216        True
# Jul                100325961.5  74929069.5      77.226928        True
# Jun                 69433334.5  43456564.5      64.085483        True
# Sep                 54323210.0  34108587.0      64.452344        True
# Nov                 77733867.0  65945357.0      75.202403        True
# Mar                 69821476.0  56002056.0      68.092879        True

# %%
mid['production_budget'].mean()
# Out:
# 22412655.086848635

# %%
mid.groupby("release_month").mean().sort_values(by="profit_margin", ascending=False)
# Out:
#                       Gross  release_year  runtime_minutes  production_budget  \
# release_month
# Jul            5.459669e+07   2014.857143       103.789712       2.194643e+07
# Nov            4.716320e+07   2015.066667       109.424710       2.084000e+07
# Mar            4.775122e+07   2015.304348       104.826087       1.764348e+07
# Feb            5.215793e+07   2015.148148       107.004146       2.218519e+07
# Jun            4.887143e+07   2015.423077       108.615385       2.244231e+07
# May            5.320743e+07   2016.086957       103.830953       2.420870e+07
# Jan            3.980004e+07   2015.166667       104.919776       2.327500e+07
# Sep            4.181499e+07   2014.351351       107.435458       2.171892e+07
# Dec            4.728461e+07   2015.113636       113.532903       2.375909e+07
# Aug            5.030806e+07   2014.805556       105.114220       2.363889e+07
# Oct            4.264035e+07   2014.897436       108.059892       2.344872e+07
# Apr            3.896812e+07   2015.000000       107.549942       2.262821e+07
#
#                worldwide_gross        profit  profit_margin  profitable
# release_month
# Jul               1.155384e+08  9.359199e+07      71.681380        True
# Nov               9.921243e+07  7.837243e+07      68.326664        True
# Mar               7.678766e+07  5.914418e+07      65.658776        True
# Feb               9.263181e+07  7.044662e+07      63.644002        True
# Jun               9.157530e+07  6.913300e+07      62.679389        True
# May               8.975617e+07  6.554748e+07      62.487700        True
# Jan               8.613088e+07  6.285588e+07      62.351666        True
# Sep               8.615400e+07  6.443508e+07      61.699281        True
# Dec               8.971832e+07  6.595923e+07      61.652930        True
# Aug               8.590220e+07  6.226331e+07      61.053600        True
# Oct               8.809233e+07  6.464361e+07      58.891723        True
# Apr               7.497384e+07  5.234563e+07      55.756478        True

# %%
mid.groupby("release_month").sum().sort_values(by="worldwide_gross", ascending=False)
# Out:
#                     Gross  release_year  runtime_minutes  production_budget  \
# release_month
# Nov            2122344087         90678      4924.111930       9.378000e+08
# Dec            2080523044         88665      4995.447721       1.045400e+09
# Oct            1662973831         78581      4214.335791       9.145000e+08
# Jul            1528707432         56416      2906.111930       6.145000e+08
# Sep            1547154763         74531      3975.111930       8.036000e+08
# Jan            1432801503         72546      3777.111930       8.379000e+08
# Aug            1811090199         72533      3784.111930       8.510000e+08
# Apr            1519756823         78585      4194.447721       8.825000e+08
# Feb            1408264239         54409      2889.111930       5.990000e+08
# Jun            1270657187         52401      2824.000000       5.835000e+08
# May            1223770974         46370      2388.111930       5.568000e+08
# Mar            1098278163         46352      2411.000000       4.058000e+08
#
#                worldwide_gross        profit  profit_margin  profitable
# release_month
# Nov               4.464559e+09  3.526759e+09    3074.699902          45
# Dec               3.947606e+09  2.902206e+09    2712.728922          44
# Oct               3.435601e+09  2.521101e+09    2296.777216          39
# Jul               3.235076e+09  2.620576e+09    2007.078640          28
# Sep               3.187698e+09  2.384098e+09    2282.873405          37
# Jan               3.100712e+09  2.262812e+09    2244.659992          36
# Aug               3.092479e+09  2.241479e+09    2197.929592          36
# Apr               2.923980e+09  2.041480e+09    2174.502650          39
# Feb               2.501059e+09  1.902059e+09    1718.388045          27
# Jun               2.380958e+09  1.797458e+09    1629.664114          26
# May               2.064392e+09  1.507592e+09    1437.217101          23
# Mar               1.766116e+09  1.360316e+09    1510.151851          23

# %% [markdown]
# These groupbys above on the mid df reveal interesting insights on what directors, months, and genres are more profitable. As can be shown in the above lines of code, mid budget movies that release in November or July have generally higher profits and profit margins, and lower production budgets. Also, one of the most profitable directors of mid budget movies is Andy Muschietti, who has directed two mainstream horror movies, the IT series. On that note, the horror genre is one of the most profitable genres of the mid budget movies. Therefore, it makes the most sense to release a mid budget horror movie in July or November, with the director being Andy Muschietti.

# %% [markdown]
# These next lines of code will be groupbys of the high df, give back the result of the most profitable directors in the susbset of profitable high budget movies that were released from 2012 onwards.

# %%
high.groupby("director").median().sort_values(by="profit_margin", ascending=False).head(10)
# Out:
#                      Gross  release_year  runtime_minutes  production_budget  \
# director
# Pierre Coffin  336045770.0        2015.0         91.00000         75000000.0
# Jon Favreau    543638043.0        2019.0        107.11193         79300000.0
# Jake Kasdan    404515480.0        2017.0        119.00000         90000000.0
# Adam Green     400738009.0        2013.0         93.00000        150000000.0
# J.A. Bayona    417719760.0        2018.0        128.00000        170000000.0
# Gary Breslin   213515506.0        2018.0         92.00000        116000000.0
# Phil Lord      224740014.5        2014.0        106.00000         55000000.0
# James Foley    107494505.0        2017.5        111.50000         55000000.0
# Ryan Coogler   700059566.0        2018.0        134.00000        200000000.0
# Ryan Fleck     426829839.0        2019.0        123.00000        175000000.0
#
#                worldwide_gross        profit  profit_margin  profitable
# director
# Pierre Coffin     1.034728e+09  9.597278e+08      92.751717        True
# Jon Favreau       9.862149e+08  9.069149e+08      91.959156        True
# Jake Kasdan       9.644962e+08  8.744962e+08      90.668703        True
# Adam Green        1.272470e+09  1.122470e+09      88.211902        True
# J.A. Bayona       1.305773e+09  1.135773e+09      86.980890        True
# Gary Breslin      8.536286e+08  7.376286e+08      86.410952        True
# Phil Lord         3.945316e+08  3.395316e+08      85.900650        True
# James Foley       3.763746e+08  3.213746e+08      85.384293        True
# Ryan Coogler      1.348258e+09  1.148258e+09      85.166046        True
# Ryan Fleck        1.123062e+09  9.480616e+08      84.417595        True

# %%
high.groupby("director").sum().sort_values(by="Gross", ascending=False).head(10)
# Out:
#                         Gross  release_year  runtime_minutes  \
# director
# Anthony Russo      2205039403          8067        613.00000
# J.J. Abrams        1165440886          4028        268.00000
# Francis Lawrence   1090402339          8060        546.00000
# Joss Whedon        1082363778          4027        284.00000
# Pierre Coffin       968735455          6045        278.00000
# Christopher Nolan   882708767          8063        546.11193
# James Wan           874125282          8062        520.00000
# Zack Snyder         850430007          6046        414.00000
# Peter Jackson       816490211          6039        474.00000
# James Gunn          778807126          6052        364.11193
#
#                    production_budget  worldwide_gross        profit  \
# director
# Anthony Russo            772722794.0     4.079279e+09  3.306557e+09
# J.J. Abrams              242722794.0     6.440554e+08  4.013326e+08
# Francis Lawrence         484000000.0     2.426382e+09  1.942382e+09
# Joss Whedon              555600000.0     2.920950e+09  2.365350e+09
# Pierre Coffin            225000000.0     3.170281e+09  2.945281e+09
# Christopher Nolan        642722794.0     2.427330e+09  1.784607e+09
# James Wan                455445588.0     3.018965e+09  2.563519e+09
# Zack Snyder              775000000.0     2.191445e+09  1.416445e+09
# Peter Jackson            750000000.0     2.922948e+09  2.172948e+09
# James Gunn               275445588.0     1.124215e+09  8.487696e+08
#
#                    profit_margin  profitable
# director
# Anthony Russo         309.786021           4
# J.J. Abrams           129.506109           2
# Francis Lawrence      296.732834           4
# Joss Whedon           161.613682           2
# Pierre Coffin         278.581116           3
# Christopher Nolan     290.028955           4
# James Wan             313.855008           4
# Zack Snyder           191.763379           3
# Peter Jackson         222.947397           3
# James Gunn            218.263159           3

# %%
high.groupby("release_month").sum().sort_values(by="worldwide_gross", ascending=False)
# Out:
#                     Gross  release_year  runtime_minutes  production_budget  \
# release_month
# Nov            7966501551        183513     10005.126676       7.733045e+09
# Jul            7721364741        189547     10108.567024       7.367668e+09
# Jun            7944426608        167362      9127.007373       7.240153e+09
# May            8003378696        165332      8987.007373       7.794462e+09
# Mar            6016447074        199671     10600.343164       7.735536e+09
# Dec            7393785100        163311      9648.567024       5.959840e+09
# Aug            3980689809        225884     11548.469839       6.842774e+09
# Feb            4435394742        185573      9814.678954       5.798982e+09
# Apr            4270251823        153272      7940.671582       5.133813e+09
# Oct            3013110834        149236      8096.790885       4.544754e+09
# Sep            2736945624        153268      7855.567024       4.334922e+09
# Jan            1118844581         94811      5331.895442       2.623912e+09
#
#                worldwide_gross        profit  profit_margin  profitable
# release_month
# Nov               2.775863e+10  2.002559e+10    6238.534050          91
# Jul               2.694817e+10  1.958050e+10    6393.224895          94
# Jun               2.686191e+10  1.962175e+10    5633.811643          83
# May               2.565812e+10  1.786366e+10    5464.059190          82
# Mar               2.364358e+10  1.590805e+10    6277.214065          99
# Dec               2.205330e+10  1.609346e+10    5593.063459          81
# Aug               2.142362e+10  1.458085e+10    7462.614363         112
# Feb               1.998047e+10  1.418149e+10    6138.219119          92
# Apr               1.977784e+10  1.464403e+10    5291.879035          76
# Oct               1.473100e+10  1.018625e+10    4874.904877          74
# Sep               1.423868e+10  9.903759e+09    5166.589368          76
# Jan               8.713378e+09  6.089466e+09    3219.660793          47

# %%
s = high.groupby("genre1").mean().sort_values(by="profit_margin", ascending=False).head(10)
s
# Out:
#                     Gross  release_year  runtime_minutes  production_budget  \
# genre1
# Animation    9.273766e+07   2018.125000        97.541974       6.547960e+07
# Thriller     4.788691e+07   2020.000000        96.537310       6.326900e+07
# Fantasy      1.612884e+08   2018.000000       101.407954       9.697426e+07
# Biography    2.335119e+07   2016.548780       113.729067       5.403371e+07
# Mystery      5.576526e+06   2019.250000       103.027983       5.272279e+07
# Sci-Fi       2.321619e+07   2019.500000        74.277983       5.272279e+07
# Horror       3.356417e+07   2018.257143        97.165454       5.726084e+07
# Drama        2.442794e+07   2017.637838       108.649453       5.704436e+07
# Crime        2.209798e+07   2017.733333       110.526117       5.361157e+07
# Documentary  1.008929e+07   2016.540984        77.453632       5.496594e+07
#
#              worldwide_gross        profit  profit_margin  profitable
# genre1
# Animation       2.853376e+08  2.198580e+08      73.275313        True
# Thriller        2.894996e+08  2.262306e+08      72.866923        True
# Fantasy         3.363415e+08  2.393672e+08      71.465472        True
# Biography       1.912807e+08  1.372470e+08      70.191354        True
# Mystery         1.766738e+08  1.239510e+08      70.158118        True
# Sci-Fi          1.766738e+08  1.239510e+08      70.158118        True
# Horror          1.895304e+08  1.322696e+08      69.665775        True
# Drama           1.880826e+08  1.310382e+08      68.746064        True
# Crime           1.807777e+08  1.271661e+08      68.598070        True
# Documentary     1.760280e+08  1.210620e+08      68.445650        True

# %%
high.groupby("genre1").mean().sort_values(by="profit", ascending=False).head(10)
# Out:
#                   Gross  release_year  runtime_minutes  production_budget  \
# genre1
# Action     1.200113e+08   2016.091525       118.740221       9.888913e+07
# Adventure  1.157540e+08   2016.016949       103.861686       9.011494e+07
# Fantasy    1.612884e+08   2018.000000       101.407954       9.697426e+07
# Thriller   4.788691e+07   2020.000000        96.537310       6.326900e+07
# Animation  9.273766e+07   2018.125000        97.541974       6.547960e+07
# Biography  2.335119e+07   2016.548780       113.729067       5.403371e+07
# Horror     3.356417e+07   2018.257143        97.165454       5.726084e+07
# Drama      2.442794e+07   2017.637838       108.649453       5.704436e+07
# Crime      2.209798e+07   2017.733333       110.526117       5.361157e+07
# Mystery    5.576526e+06   2019.250000       103.027983       5.272279e+07
#
#            worldwide_gross        profit  profit_margin  profitable
# genre1
# Action        3.416936e+08  2.428045e+08      64.360636        True
# Adventure     3.306295e+08  2.405146e+08      65.874526        True
# Fantasy       3.363415e+08  2.393672e+08      71.465472        True
# Thriller      2.894996e+08  2.262306e+08      72.866923        True
# Animation     2.853376e+08  2.198580e+08      73.275313        True
# Biography     1.912807e+08  1.372470e+08      70.191354        True
# Horror        1.895304e+08  1.322696e+08      69.665775        True
# Drama         1.880826e+08  1.310382e+08      68.746064        True
# Crime         1.807777e+08  1.271661e+08      68.598070        True
# Mystery       1.766738e+08  1.239510e+08      70.158118        True

# %%
n = high.groupby("genre2").sum().sort_values(by="Gross", ascending=False).head(10)
n
# Out:
#                  Gross  release_year  runtime_minutes  production_budget  \
# genre2
# Adventure  26863891016        310458     18550.455094       1.956479e+10
# Animation   9256192527        141108      6701.895442       5.848593e+09
# Drama       6557815528        415388     23518.686327       1.184821e+10
# Comedy      3353145809        124989      6715.783512       3.784647e+09
# Crime       2823554783        106892      6184.783512       3.367189e+09
# Family      2162656938         38330      2225.335791       2.187682e+09
# Fantasy     1670719143         52405      2936.335791       2.094896e+09
# Thriller    1555875808         68591      3608.895442       2.240570e+09
# Mystery      995907701         48388      2549.335791       1.497733e+09
# Romance      746379820         70586      3843.447721       2.044407e+09
#
#            worldwide_gross        profit  profit_margin  profitable
# genre2
# Adventure     7.044876e+10  5.088397e+10    9989.763288         154
# Animation     2.388743e+10  1.803884e+10    4786.000652          70
# Drama         4.054730e+10  2.869909e+10   14158.858063         206
# Comedy        1.195219e+10  8.167539e+09    4031.693239          62
# Crime         1.165381e+10  8.286621e+09    3486.347958          53
# Family        6.043039e+09  3.855357e+09    1123.889526          19
# Fantasy       6.312838e+09  4.217942e+09    1522.719034          26
# Thriller      7.305475e+09  5.064905e+09    2292.707299          34
# Mystery       4.952328e+09  3.454595e+09    1669.699287          24
# Romance       6.882918e+09  4.838511e+09    2455.150457          35

# %%
high.groupby("genre2").sum().sort_values(by="profit_margin", ascending=False).head(10)
# Out:
#                  Gross  release_year  runtime_minutes  production_budget  \
# genre2
# Drama       6557815528        415388     23518.686327       1.184821e+10
# Adventure  26863891016        310458     18550.455094       1.956479e+10
# Animation   9256192527        141108      6701.895442       5.848593e+09
# Comedy      3353145809        124989      6715.783512       3.784647e+09
# Crime       2823554783        106892      6184.783512       3.367189e+09
# Romance      746379820         70586      3843.447721       2.044407e+09
# Thriller    1555875808         68591      3608.895442       2.240570e+09
# Mystery      995907701         48388      2549.335791       1.497733e+09
# Horror       728644572         44391      2259.671582       1.300933e+09
# Fantasy     1670719143         52405      2936.335791       2.094896e+09
#
#            worldwide_gross        profit  profit_margin  profitable
# genre2
# Drama         4.054730e+10  2.869909e+10   14158.858063         206
# Adventure     7.044876e+10  5.088397e+10    9989.763288         154
# Animation     2.388743e+10  1.803884e+10    4786.000652          70
# Comedy        1.195219e+10  8.167539e+09    4031.693239          62
# Crime         1.165381e+10  8.286621e+09    3486.347958          53
# Romance       6.882918e+09  4.838511e+09    2455.150457          35
# Thriller      7.305475e+09  5.064905e+09    2292.707299          34
# Mystery       4.952328e+09  3.454595e+09    1669.699287          24
# Horror        4.340097e+09  3.039164e+09    1546.008555          22
# Fantasy       6.312838e+09  4.217942e+09    1522.719034          26

# %%
high.groupby("release_month").sum().sort_values(by="worldwide_gross", ascending=False).head(5)
# Out:
#                     Gross  release_year  runtime_minutes  production_budget  \
# release_month
# Nov            7966501551        183513     10005.126676       7.733045e+09
# Jul            7721364741        189547     10108.567024       7.367668e+09
# Jun            7944426608        167362      9127.007373       7.240153e+09
# May            8003378696        165332      8987.007373       7.794462e+09
# Mar            6016447074        199671     10600.343164       7.735536e+09
#
#                worldwide_gross        profit  profit_margin  profitable
# release_month
# Nov               2.775863e+10  2.002559e+10    6238.534050          91
# Jul               2.694817e+10  1.958050e+10    6393.224895          94
# Jun               2.686191e+10  1.962175e+10    5633.811643          83
# May               2.565812e+10  1.786366e+10    5464.059190          82
# Mar               2.364358e+10  1.590805e+10    6277.214065          99

# %%
high.groupby("release_month").sum().sort_values(by="profit_margin", ascending=False).head(5)
# Out:
#                     Gross  release_year  runtime_minutes  production_budget  \
# release_month
# Aug            3980689809        225884     11548.469839       6.842774e+09
# Jul            7721364741        189547     10108.567024       7.367668e+09
# Mar            6016447074        199671     10600.343164       7.735536e+09
# Nov            7966501551        183513     10005.126676       7.733045e+09
# Feb            4435394742        185573      9814.678954       5.798982e+09
#
#                worldwide_gross        profit  profit_margin  profitable
# release_month
# Aug               2.142362e+10  1.458085e+10    7462.614363         112
# Jul               2.694817e+10  1.958050e+10    6393.224895          94
# Mar               2.364358e+10  1.590805e+10    6277.214065          99
# Nov               2.775863e+10  2.002559e+10    6238.534050          91
# Feb               1.998047e+10  1.418149e+10    6138.219119          92

# %%
z = high.groupby("release_month").mean().sort_values(by="production_budget", ascending=False)
z
# Out:
#                       Gross  release_year  runtime_minutes  production_budget  \
# release_month
# May            9.760218e+07   2016.243902       109.597651       9.505442e+07
# Jun            9.571598e+07   2016.409639       109.963944       8.723075e+07
# Nov            8.754397e+07   2016.626374       109.946447       8.497851e+07
# Jul            8.214218e+07   2016.457447       107.537947       7.837944e+07
# Mar            6.077219e+07   2016.878788       107.074173       7.813673e+07
# Dec            9.128130e+07   2016.185185       119.118111       7.357827e+07
# Apr            5.618752e+07   2016.736842       104.482521       6.755017e+07
# Feb            4.821081e+07   2017.097826       106.681293       6.303241e+07
# Oct            4.071771e+07   2016.702703       109.416093       6.141559e+07
# Aug            3.554187e+07   2016.821429       103.111338       6.109620e+07
# Sep            3.601244e+07   2016.684211       103.362724       5.703845e+07
# Jan            2.380520e+07   2017.255319       113.444584       5.582791e+07
#
#                worldwide_gross        profit  profit_margin  profitable
# release_month
# May               3.129039e+08  2.178495e+08      66.634868        True
# Jun               3.236374e+08  2.364067e+08      67.877249        True
# Nov               3.050399e+08  2.200614e+08      68.555319        True
# Jul               2.866826e+08  2.083032e+08      68.013031        True
# Mar               2.388241e+08  1.606873e+08      63.406203        True
# Dec               2.722630e+08  1.986847e+08      69.050166        True
# Apr               2.602347e+08  1.926846e+08      69.629987        True
# Feb               2.171791e+08  1.541466e+08      66.719773        True
# Oct               1.990676e+08  1.376520e+08      65.877093        True
# Aug               1.912824e+08  1.301862e+08      66.630485        True
# Sep               1.873511e+08  1.303126e+08      67.981439        True
# Jan               1.853910e+08  1.295631e+08      68.503421        True

# %%
high['production_budget'].mean()
# Out:
# 72601648.3753724

# %% [markdown]
# It is best to release a high budget movie in the months of March, July, November. Generally, as these are prime markets for high budget movies, the average budgets are generally higher than those for movies released in other months. The average budget of a high budget movie is roughly 72 million. The average movie budget for films released in Novemeber, July, March, is 85 million, 78 million, and 78 million respectively. Generally, animation is the most profitable genre in high budget movies. One of the most profitable directors of hgih budget movies is Pierre Coffin, who is almost singlehandedly responsibsle for the success of the Minions movies. Therefore, if an animated film should be created by Microsoft Studios, it would make sense to hire Pierre Coffin to direct this movie.

# %%
import seaborn as sns

# %%
values = ['high_tier']
df2 = df[df.budget_tier.isin(values) == False]

# %%
tiers = ['Low Tier', 'Mid Tier', 'High Tier']
fig, ax = plt.subplots(figsize = (20,10))
sns.boxplot(x = 'budget_tier', y = 'profit_margin', 
            data = df2, orient = 'v')
ax.set_title('Movie Profitability by Budget Tiers', size = 40)
ax.set_xlabel('Budget Tiers', fontsize = 30)
ax.tick_params(labelsize = 25)
ax.set_ylabel('Profit Margin (%)', fontsize = 30)
plt.tight_layout()

# %%
values = ['Fantasy', 'Animation', 'Crime']
low = low[low.genre1.isin(values) == False]

# %%
fig, ax = plt.subplots(figsize = (20,10))
sns.boxplot(x = 'genre1', y = 'profit_margin', 
            data = low, orient = 'v')
ax.set_title('Profitability of Low Budget Movies by Genre', size = 40)
ax.set_xlabel('Genres', fontsize = 30)
ax.set_ylabel('Profit Margin (%)', fontsize = 30)
ax.tick_params(labelsize = 25, rotation = 20)
plt.tight_layout()

# %%
dl
# Out:
# genre1
# Horror       1.162993e+08
# Action       1.014371e+08
# Adventure    9.158905e+07
# Comedy       8.828258e+07
# Drama        8.159496e+07
# Name: worldwide_gross, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (20,10))
ax.bar(dl.keys(), dl, color = "pink")
ax.set_xlabel('Movie Genre', fontsize = 30)
ax.tick_params(labelsize = 25, rotation = 20)
ax.set_ylabel("Worldwide Gross", fontsize = 30)
ax.set_title('Worldwide Gross of Mid Budget Movies by Genre', fontsize = 40)
ax.get_yaxis().set_major_formatter(
    mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.grid()
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize = (20,10))
sns.boxplot(x = dg.keys(), y = dg['worldwide_gross'], 
            data = dg, orient = 'v')
ax.set_title('Profitability of Mid Budget Movies by Genre', size = 40)
ax.set_xlabel('Genres', fontsize = 30)
ax.tick_params(labelsize = 25, rotation = 20)
ax.set_ylabel('Profit Margin', fontsize = 30)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-6fa973e33393> in <module>
#       1 fig, ax = plt.subplots(figsize = (20,10))
# ----> 2 sns.boxplot(x = dg.keys(), y = dg['worldwide_gross'],
#       3             data = dg, orient = 'v')
#       4 ax.set_title('Profitability of Mid Budget Movies by Genre', size = 40)
#       5 ax.set_xlabel('Genres', fontsize = 30)
#
# NameError: name 'dg' is not defined

# %%
fig, ax = plt.subplots(figsize = (20,10))
ax.bar(n.keys(), n, color = "blue")
ax.set_xlabel('Movie Genre', fontsize = 30)
ax.set_ylabel("Worldwide Gross", fontsize = 30)
ax.set_title('Worldwide Gross of High Budget Movies by Genre', fontsize = 40)
plt.tight_layout()

# %%
n

# %%
b = high.groupby("genre1").mean().sort_values(by="production_budget", ascending=False).head(10)
b

# %%
b = b['production_budget'].head(10)
b

# %%
fig, ax = plt.subplots(figsize = (20,10))
ax.bar(b.keys(), b, color = "blue")
ax.set_xlabel('Movie Genre', fontsize = 30)
ax.set_ylabel("Worldwide Gross", fontsize = 30)
ax.set_title('Worldwide Gross of High Budget Movies by Genre', fontsize = 40)
plt.tight_layout()

# %%
c = high.groupby("genre1").mean().sort_values(by="runtime_minutes", ascending=False).head(10)
c

# %%
c = c['runtime_minutes'].head(10)
c

# %%
fig, ax = plt.subplots(figsize = (20,10))
ax.bar(c.keys(), c, color = "blue")
ax.set_xlabel('Movie Genre', fontsize = 30)
ax.set_ylabel("Movie runtime in minutes", fontsize = 30)
ax.set_title('Runtime of High Budget Movies by Genre', fontsize = 40)
plt.tight_layout()

# %%
xw = xw['profit_margin'].head(10)
xw

# %%
fig, ax = plt.subplots(figsize = (20,10))
ax.bar(xw.keys(), xw, color = "blue")
ax.set_xlabel('Director', fontsize = 30)
ax.set_ylabel("Profit Margin ", fontsize = 30)
ax.set_title('Low Budget Film Directors by Profit Margin', fontsize = 40)
plt.tight_layout()

# %%
import matplotlib as mpl
fig, ax = plt.subplots(figsize = (20,10))
ax.bar(xy.keys(), xy, color = "blue")
ax.set_xlabel('Director', fontsize = 30)
ax.set_ylabel("Worldwide Gross ($)", fontsize = 30)
ax.tick_params(labelsize = 20, rotation = 35)
ax.set_title('Low Budget Film Directors by Worldwide Gross', fontsize = 40)
ax.get_yaxis().set_major_formatter(
    mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.grid()
plt.tight_layout()

# %%
xn = xn['worldwide_gross'].head(10)
xwfig, ax = plt.subplots(figsize = (20,10))
ax.bar(xn.keys(), xn, color = "blue")
ax.set_xlabel('Director', fontsize = 30)
ax.set_ylabel("Worldwide Gross", fontsize = 30)
ax.tick_params(labelsize = 20, rotation = 35)
ax.set_title('Mid Budget Film Directors by Worldwide Gross', fontsize = 40)
ax.get_yaxis().set_major_formatter(
    mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.grid()
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize = (20,10))
ax.bar(xd.keys(), xd, color = "orange")
ax.set_xlabel('Month', fontsize = 30)
ax.set_ylabel("Profit ($)", fontsize = 30)
ax.tick_params(labelsize = 20)
ax.set_title('Low Budgets Movies by Monthly Profit ', fontsize = 40)
ax.get_yaxis().set_major_formatter(
    mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.grid()
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize = (20,10))
ax.bar(xc.keys(), xc, color = "blue")
ax.set_xlabel('Month', fontsize = 30)
ax.set_ylabel("Production Budget", fontsize = 30)
ax.tick_params(labelsize = 15, rotation = 35)
ax.set_title('Low Budgets Movies by Monthly Production Budget', fontsize = 40)
ax.get_yaxis().set_major_formatter(
    mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.grid()
plt.tight_layout()

# %%
low['release_month'].value_counts()

# %%
tr = mid.groupby("release_month").sum().sort_values(by="profit", ascending=False)
tr = tr['profit'].head()
tr

# %%
fig, ax = plt.subplots(figsize = (20,10))
ax.bar(tr.keys(), tr, color = "orange")
ax.set_xlabel('Month', fontsize = 30)
ax.set_ylabel("Production Budget", fontsize = 30)
ax.tick_params(labelsize = 15, rotation = 35)
ax.set_title('Mid Budgets Movies by Monthly Production Budget', fontsize = 40)
ax.get_yaxis().set_major_formatter(
    mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.grid()
plt.tight_layout()

# %%
ty = mid.groupby("release_month").sum().sort_values(by="profit", ascending=False).head(5)
ty = ty['profit']
ty
fig, ax = plt.subplots(figsize = (20,10))
ax.bar(ty.keys(), ty, color = "orange")
ax.set_xlabel('Month', fontsize = 30)
ax.set_ylabel("Profit ($)", fontsize = 30)
ax.tick_params(labelsize = 20)
ax.set_title('Mid Budgets Movies by Monthly Profit ($) ', fontsize = 40)
ax.get_yaxis().set_major_formatter(
    mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.grid()
plt.tight_layout()
